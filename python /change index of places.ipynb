# %%
import pymysql
import requests

# %%
db = pymysql.connect(
    user='jisoo',
    passwd='53392c',
    db='caps',
    host='165.194.104.23',
    port=6689,
    charset='UTF8'
)

cursor = db.cursor(pymysql.cursors.DictCursor)

# %%
select_query = "SELECT id, content_id FROM final_place order by id"
cursor.execute(select_query)
results = cursor.fetchall()

# %%
count = 0
for result in results:
    count += 1
    place_id = str(result['id'])
    content_id = str(result['content_id'])
    update_query = "UPDATE final_place SET idx = " + str(count) + " WHERE content_id = " + str(content_id)
    cursor.execute(update_query)
    db.commit()
    print("updated")
# Out:
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# ...

# %%
select_query = "SELECT id, content_id FROM final_place_korean order by id"
cursor.execute(select_query)
results = cursor.fetchall()

# %%
count = 0
for result in results:
    count += 1
    id = str(result['id'])
    content_id = str(result['content_id'])
    update_query = "UPDATE final_place_korean SET place_id = " + str(count) + " WHERE content_id = " + str(content_id)
    cursor.execute(update_query)
    db.commit()
    print("updated")
# Out:
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# ...
