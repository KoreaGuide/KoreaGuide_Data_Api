# %%
import pymysql
import requests

# %%
db = pymysql.connect(
    user='root',
    passwd='dlatjsgh99',
    db='caps_data',
    host='localhost',
    port=3306,
    charset='UTF8'
)

cursor = db.cursor(pymysql.cursors.DictCursor)

# %%
select_query = "SELECT id, contentid FROM place_tb"
cursor.execute(select_query)
results = cursor.fetchall()

# %%
for result in results:
    place_id = str(result['id'])
    content_id = str(result['contentid'])
    insert_query = "INSERT IGNORE INTO mapping_tb(placeid, contentid) VALUES(%s, %s)"
    values = (place_id, content_id)
    cursor.execute(insert_query, values)
    db.commit()
    print("inserted")
# Out:
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# ...

# %%
select_query = "SELECT * FROM word3_tb"
cursor.execute(select_query)
results = cursor.fetchall()

# %%
for result in results:
    word_id = str(result['id'])
    print(word_id)
    place_count = result['place_count']
    print(place_count)
    if(place_count > 50):
        place_count = 50
    for i in range(1, place_count + 1):
        content_id_idx = "place" + str(i)
        print(content_id_idx)
        
        content_id = result[content_id_idx]
        print(content_id)
        
        select_query = "SELECT wordcount FROM mapping_tb WHERE contentid = " + str(content_id)
        cursor.execute(select_query)
        temp_result = cursor.fetchone()
        
        word_count = temp_result['wordcount']
        print(word_count)
        word_count = word_count + 1
        if word_count > 50:
            continue
        update_query = "UPDATE mapping_tb SET wordcount = " + str(word_count) + ", word" + str(word_count) + " = " + word_id + " WHERE contentid = " + str(content_id)
        cursor.execute(update_query)
        db.commit()
        print("word_id : " + word_id)
# Out:
# 1
# 90
# place1
# 264337
# 50
# place2
# 264550
# 4
# word_id : 1
# place3
# 561382
# 4
# word_id : 1
# place4
# 264122
# 6
# word_id : 1
# place5
# 264348
# 16
# word_id : 1
# place6
# 264312
# 2
# word_id : 1
# place7
# 668511
# 4
# word_id : 1
# place8
# 1323377
# 2
# word_id : 1
# place9
# 264329
# 11
# word_id : 1
# place10
# 2003918
# 6
# word_id : 1
# place11
# 1061818
# 6
# word_id : 1
# place12
# 264315
# 11
# word_id : 1
# place13
# 2037327
# 5
# word_id : 1
# place14
# 1348417
# 7
# word_id : 1
# place15
# 264235
# 2
# word_id : 1
# place16
# 264212
# 2
# word_id : 1
# place17
# 264204
# 4
# word_id : 1
# place18
# 264199
# 4
# word_id : 1
# place19
# 264490
# 4
# word_id : 1
# place20
# 264363
# 4
# word_id : 1
# place21
# 264410
# 11
# word_id : 1
# place22
# 1061693
# 5
# word_id : 1
# place23
# 264387
# 5
# word_id : 1
# place24
# 264395
# 2
# word_id : 1
# place25
# 1342122
# 4
# word_id : 1
# place26
# 264211
# 6
# word_id : 1
# place27
# 264219
# 4
# word_id : 1
# ...
