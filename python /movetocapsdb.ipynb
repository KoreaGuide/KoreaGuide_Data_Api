# %%
import pymysql
import requests

db = pymysql.connect(
    user='root',
    passwd='dlatjsgh99',
    db='caps_data',
    host='localhost',
    port=3306,
    charset='UTF8'
)


capsdb = pymysql.connect(
    user='jisoo',
    passwd='53392c',
    db='caps',
    host='165.194.104.23',
    port=6689,
    charset='UTF8'
)


cursor = db.cursor(pymysql.cursors.DictCursor)
capscursor = capsdb.cursor(pymysql.cursors.DictCursor)
select_query = "SELECT * FROM new_final_place_tb"
cursor.execute(select_query)
results = cursor.fetchall()

# %%
for result in results:
    
    insert_query = "INSERT INTO new_final_place(title, address1, areacode, first_image, firstimage2, mapx, mapy, overview_eng, cat1code, cat2code, cat3code) VALUES(%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)"
    values = (str(result['id']), result['title'], result['addr1'], str(result['contentid']), str(result['areacode']), result['firstimage'], result['firstimage2'], result['mapx'], result['mapy'], result['overview_eng'], result['cat1code'], result['cat2code'], result['cat3code'])
    capscursor.execute(insert_query, values)
    capsdb.commit()

# %%
select_query = "SELECT * FROM overview_tb"
cursor.execute(select_query)
results = cursor.fetchall()

# %%
for result in results:
    contentid = str(result['contentid'])
    overview_kor = result['overview_kor']
    update_query = "UPDATE final_places SET overview_kor = \'" + overview_kor + "\' WHERE contentid = " + contentid
    capscursor.execute(update_query)
    print(contentid)
    capsdb.commit()
# Out:
# 264337
# 264152
# 264550
# 561382
# 264354
# 264122
# 264348
# 264312
# 1011983
# 264116
# 1326972
# 897540
# 264316
# 264320
# 264350
# 264351
# 264594
# 264352
# 668511
# 789696
# 264134
# 264571
# 264138
# 1323377
# 789703
# 264340
# 2475097
# 1051832
# 1341981
# 264329
# 264455
# 1998305
# 2003918
# 1796840
# 264473
# 264478
# 264257
# 264308
# 1061818
# 264223
# 264315
# 2037327
# 1013338
# 264614
# 1389275
# 1060117
# 264317
# 1887247
# 1838143
# 264135
# 1348417
# 1382671
# 1542646
# 1562674
# 264235
# 264121
# 264212
# 264204
# 264199
# 264490
# 264363
# 1051901
# 264487
# 264410
# 264489
# 615850
# 616280
# 1066062
# 1949711
# 1272552
# 823350
# 1057604
# 1847807
# 264580
# 2504025
# 1461356
# 1061693
# 264387
# 776712
# 1057592
# 616199
# 778834
# 822969
# 819651
# 816519
# 822835
# 264395
# 1751677
# 2525539
# 264609
# 1066116
# 778567
# 264391
# 1342122
# 264211
# 264219
# 264130
# 264253
# 264615
# 264190
# 264215
# 658343
# 264433
# 264165
# 264622
# 264248
# 264189
# ...
