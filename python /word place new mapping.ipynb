# %%
import pymysql
import requests

# %%
db = pymysql.connect(
    user='jisoo',
    passwd='53392c',
    db='caps',
    host='165.194.104.23',
    port=6689,
    charset='UTF8'
)


cursor = db.cursor(pymysql.cursors.DictCursor)

# %%
select_query = "SELECT * FROM mapping"
cursor.execute(select_query)
results = cursor.fetchall()

# %%
for result in results:
    place_id = str(result['place_id'])
    print(place_id)
    for i in range(1, 51):
        idx = 'word' + str(i)
        word_id = str(result[idx])
        if result[idx] != 0 :
            insert_query = "INSERT IGNORE INTO new_mapping(place_id, word_id) VALUES(%s, %s)"
            values = (place_id, word_id)
            cursor.execute(insert_query, values)
            db.commit()
            print("inserted " + idx)
        else :
            print("ignored " + idx)
# Out:
# 312
# inserted word1
# inserted word2
# inserted word3
# inserted word4
# inserted word5
# inserted word6
# inserted word7
# inserted word8
# inserted word9
# inserted word10
# inserted word11
# inserted word12
# inserted word13
# inserted word14
# inserted word15
# inserted word16
# inserted word17
# inserted word18
# inserted word19
# inserted word20
# inserted word21
# inserted word22
# inserted word23
# inserted word24
# inserted word25
# inserted word26
# inserted word27
# inserted word28
# inserted word29
# inserted word30
# inserted word31
# inserted word32
# inserted word33
# inserted word34
# inserted word35
# inserted word36
# inserted word37
# inserted word38
# ignored word39
# ignored word40
# ignored word41
# ignored word42
# ignored word43
# ignored word44
# ignored word45
# ignored word46
# ignored word47
# ignored word48
# ignored word49
# ignored word50
# 10
# inserted word1
# inserted word2
# inserted word3
# inserted word4
# inserted word5
# inserted word6
# ...

# %%
select_query = "SELECT * FROM final_mapping"
cursor.execute(select_query)
results = cursor.fetchall()

# %%
for result in results:
    place_id = str(result['place_id'])
    word_id = str(result['word_id'])
    select_query = "SELECT idx from final_place where id = " + place_id
    cursor.execute(select_query)
    result = cursor.fetchone()
    new_place_id = str(result['idx'])
    update_query = "UPDATE final_mapping SET new_place_id = " + new_place_id + " where place_id = " + place_id
    cursor.execute(update_query)
    db.commit()
    print("updated")
# Out:
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# updated
# ...

# %%
select_query = "SELECT * FROM mapping"
cursor.execute(select_query)
results = cursor.fetchall()

# %%
for result in results:
    place_id = str(result['place_id'])
    print(place_id)
    select_query = "SELECT idx from final_place where id = " + place_id
    cursor.execute(select_query)
    result = cursor.fetchone()
    new_place_id = str(result['idx'])
    update_query = "UPDATE mapping SET new_place_id = " + new_place_id + " WHERE place_id = " + place_id
    cursor.execute(update_query)
    db.commit()
    print("updated")
# Out:
# 1
# updated
# 1
# updated
# 1
# updated
# 1
# updated
# 1
# updated
# 1
# updated
# 1
# updated
# 1
# updated
# 1
# updated
# 1
# updated
# 1
# updated
# 1
# updated
# 1
# updated
# 1
# updated
# 1
# updated
# 1
# updated
# 1
# updated
# 1
# updated
# 1
# updated
# 1
# updated
# 1
# updated
# 1
# updated
# 1
# updated
# 1
# updated
# 1
# updated
# 1
# updated
# 1
# updated
# 1
# updated
# 1
# updated
# 1
# updated
# 2
# updated
# 2
# updated
# 2
# updated
# 2
# updated
# 2
# updated
# 2
# updated
# 2
# updated
# 2
# updated
# 2
# updated
# 2
# updated
# 2
# updated
# 2
# updated
# 2
# updated
# 2
# updated
# 2
# updated
# 2
# updated
# 2
# updated
# 2
# updated
# 2
# updated
# 2
# updated
# 2
# updated
# 2
# updated
# 2
# updated
# 2
# updated
# 2
# updated
# 2
# updated
# 2
# updated
# 2
# updated
# 2
# updated
# 2
# updated
# 2
# updated
# 2
# updated
# 2
# updated
# 2
# updated
# 2
# updated
# 2
# updated
# 2
# updated
# 3
# updated
# 3
# updated
# 3
# updated
# 3
# updated
# 3
# ...

# %%
select_query = "SELECT * FROM mapping order by new_place_id"
cursor.execute(select_query)
results = cursor.fetchall()

# %%
count = 0
for result in results:
    count += 1
    update_query = "UPDATE mapping SET id = " + count + " WHERE place_id = " + place_id
    cursor.execute(update_query)
    db.commit()
