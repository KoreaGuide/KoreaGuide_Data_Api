# %%
"""Synthesizes speech from the input string of text or ssml.

Note: ssml must be well-formed according to:
    https://www.w3.org/TR/speech-synthesis/
"""
from google.cloud import texttospeech

# Instantiates a client
client = texttospeech.TextToSpeechClient()

# Set the text input to be synthesized
synthesis_input = texttospeech.SynthesisInput(text="Hello, World!")

# Build the voice request, select the language code ("en-US") and the ssml
# voice gender ("neutral")
voice = texttospeech.VoiceSelectionParams(
    language_code="en-US", ssml_gender=texttospeech.SsmlVoiceGender.NEUTRAL
)

# Select the type of audio file you want returned
audio_config = texttospeech.AudioConfig(
    audio_encoding=texttospeech.AudioEncoding.MP3
)

# Perform the text-to-speech request on the text input with the selected
# voice parameters and audio file type
response = client.synthesize_speech(
    input=synthesis_input, voice=voice, audio_config=audio_config
)

# The response's audio_content is binary.
with open("output.mp3", "wb") as out:
    # Write the response to the output file.
    out.write(response.audio_content)
    print('Audio content written to file "test_output.mp3"')
# Out:
# Audio content written to file "test_output.mp3"

# %%
def synthesize_text(word_id, text):
    from google.cloud import texttospeech

    client = texttospeech.TextToSpeechClient()

    input_text = texttospeech.SynthesisInput(text=text)

    # Note: the voice can also be specified by name.
    # Names of voices can be retrieved with client.list_voices().
    voice = texttospeech.VoiceSelectionParams(
        language_code="ko-KR",
        name="ko-KR-Wavenet-B", #Standard-A~D #ko-KR-Wavenet-A~D 여여남남 순
        ssml_gender=texttospeech.SsmlVoiceGender.FEMALE,
    )

    audio_config = texttospeech.AudioConfig(
        audio_encoding=texttospeech.AudioEncoding.MP3
    )

    response = client.synthesize_speech(
        request={"input": input_text, "voice": voice, "audio_config": audio_config}
    )

    # The response's audio_content is binary.
    with open(word_id + ".mp3", "wb") as out:
        out.write(response.audio_content)
        print('Audio content written to file "'+ word_id +'.mp3"')

# %%
synthesize_text("떡볶이")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-5ec5ff3bbf7e> in <module>
# ----> 1 synthesize_text("떡볶이")
#
# TypeError: synthesize_text() missing 1 required positional argument: 'text'

# %%
import pymysql
import requests

# %%
db = pymysql.connect(
    user='root',
    passwd='dlatjsgh99',
    db='caps_data',
    host='localhost',
    port=3306,
    charset='UTF8'
)

cursor = db.cursor(pymysql.cursors.DictCursor)
select_query = "SELECT id, word_kor FROM word3_tb WHERE id > 1869"
cursor.execute(select_query)
results = cursor.fetchall()

# %%
for result in results:
    word_id = result['id']
    word_kor = result['word_kor']
    
    synthesize_text(str(word_id), word_kor)
# Out:
# Audio content written to file "1870.mp3"
# Audio content written to file "1871.mp3"
# Audio content written to file "1872.mp3"
# Audio content written to file "1873.mp3"
# Audio content written to file "1874.mp3"
# Audio content written to file "1875.mp3"
# Audio content written to file "1876.mp3"
# Audio content written to file "1877.mp3"
# Audio content written to file "1878.mp3"
# Audio content written to file "1879.mp3"
# Audio content written to file "1880.mp3"
# Audio content written to file "1881.mp3"
# Audio content written to file "1882.mp3"
# Audio content written to file "1883.mp3"
# Audio content written to file "1884.mp3"
# Audio content written to file "1885.mp3"
# Audio content written to file "1886.mp3"
# Audio content written to file "1887.mp3"
# Audio content written to file "1888.mp3"
# Audio content written to file "1889.mp3"
# Audio content written to file "1890.mp3"
# Audio content written to file "1891.mp3"
# Audio content written to file "1892.mp3"
# ...

# %%
audio_link = ""
    
    update_query = "UPDATE word3_tb SET audio = " + audio_link + " WHERE id = " + id
    cursor.execute(update_query)
    db.commit()
